# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/alder.csv', sep=";")

# %%
df.head()
# Out:
#      År  Mors fødealder første barn  Fars fødealder første barn
# 0  1961                        24.6                        28.2
# 1  1962                        24.3                        27.9
# 2  1963                        24.0                        27.5
# 3  1964                        23.8                        27.2
# 4  1965                        23.6                        26.9

# %%
df.describe()
# Out:
#                 År  Mors fødealder første barn  Fars fødealder første barn
# count    61.000000                   61.000000                   61.000000
# mean   1991.000000                   26.057377                   28.811475
# std      17.752934                    2.161362                    2.015531
# min    1961.000000                   23.200000                   25.900000
# 25%    1976.000000                   24.100000                   27.100000
# 50%    1991.000000                   25.700000                   28.400000
# 75%    2006.000000                   28.100000                   30.800000
# max    2021.000000                   30.100000                   32.100000

# %%
plt.rcParams["figure.figsize"] = (16, 8)
df.plot(x='År', y=['Mors fødealder første barn', 'Fars fødealder første barn'])
plt.show()

# %%
plt.rcParams["figure.figsize"] = (16, 8)
plt.plot(df['År'], df["Mors fødealder første barn"])
plt.plot(df['År'], df["Fars fwødealder første barn"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
plt.plot(df['År'], df["Fars fødealder første barn"]-df["Mors fødealder første barn"])

# %%
plt.plot( df["Mors fødealder første barn"], df["Fars fødealder første barn"], 'o')

# %%
df["Mors fødealder første barn"]
# Out:
# 0     24.6
# 1     24.3
# 2     24.0
# 3     23.8
# 4     23.6
#       ...
# 56    29.3
# 57    29.5
# 58    29.8
# 59    29.9
# 60    30.1
# Name: Mors fødealder første barn, Length: 61, dtype: float64

# %%
mor = df["Fars fødealder første barn"]
år = df["År"]
der = []
for i in range(len(mor)-1):
    der.append((mor[i+1]-mor[i])/(år[i+1]-år[i]))
    
plt.plot(år[1:], der)

# %%
df = pd.read_csv('data/likestilling.csv', sep='\t')

# %%
df
# Out:
#            region    År  Gjennomsnittlig bruttoinntekt, menn (kr)  \
# 0   0 Hele landet  2008                                    423100
# 1   0 Hele landet  2009                                    419100
# 2   0 Hele landet  2010                                    433200
# 3   0 Hele landet  2011                                    453300
# 4   0 Hele landet  2012                                    470500
# 5   0 Hele landet  2013                                    487800
# 6   0 Hele landet  2014                                    503600
# 7   0 Hele landet  2015                                    530100
# 8   0 Hele landet  2016                                    522900
# 9   0 Hele landet  2017                                    533900
# 10  0 Hele landet  2018                                    550300
# 11  0 Hele landet  2019                                    567400
# 12  0 Hele landet  2020                                    583600
#
# ...
